# %%
import draw
import data_Manager
datas = data_Manager.Data()
import matplotlib.pyplot as plt
x = datas.train
# Out:
# Using TensorFlow backend.

# %%
data = x[12000]
min_x, max_x, min_y, max_y = draw.get_bounds(data)

# %%
draw.draw_strokes(data, svg_filename="cat.svg")
